# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#     Latitude   Longitude      Height  Magnetic North    RawXMag    RawYMag  \
# 0  42.665609   97.608523  423.920459      146.292735  -7.792499  -5.198380
# 1  43.393751   99.100289  424.078378      146.295795 -12.753663  -8.433118
# 2  44.091860  100.612700  424.228488      146.320684 -16.084578 -10.118766
# 3  44.764002  102.155430  424.371471      146.381172 -18.086969 -11.345068
# 4  45.413666  103.739068  424.507870      146.448640 -19.244625 -11.774558
#
#      RawZMag                     TimeUTC  id
# 0  13.083874  2023-04-26 21:08:19.262808   2
# 1  21.644501  2023-04-26 21:08:40.216362   3
# 2  27.788910  2023-04-26 21:09:01.045907   4
# 3  31.474634  2023-04-26 21:09:21.934935   5
# 4  34.444668  2023-04-26 21:09:43.217774   6

# %%
lat, lon = 46.2437, 6.0251

# %%
export GOOGLE_API_KEY=AIzaSyCZ9DYZcCNYeOJP73U9QszXBPropJiLvT4
# Out:
#   Cell In[13], line 1
#     export GOOGLE_API_KEY=AIzaSyCZ9DYZcCNYeOJP73U9QszXBPropJiLvT4
#            ^
# SyntaxError: invalid syntax

# %%
pip install folium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 3.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gmaps
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.8 MB/s eta 0:00:002 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076091 sha256=448846f564bf1213539eb8985a2b025759560a8834800a90cf0177ed898ce99d
#   Stored in directory: /home/linkat/.cache/pip/wheels/b6/ac/b0/f2cc081243b337b832a27835d3d80ad0c38c1d2bd5223f0f84
# Successfully built gmaps
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# The gmaps program did not work
# it gave problems in the apikey
# it was partly free, so we decided to discard it


import gmaps

# Coordenadas del punto (latitud y longitud)
latitud = 40.7128
longitud = -74.0060

# Configurar la API de Google Maps
gmaps.configure(api_key='AIzaSyCZ9DYZcCNYeOJP73U9QszXBPropJiLvT4')

# Crear un mapa centrado en las coordenadas dadas
fig = gmaps.figure(center=(latitud, longitud), zoom_level=12)

# Crear una capa de mapa satelital de Google
capa_satelite = gmaps.satellite_layer()
fig.add_layer(capa_satelite)

# Agregar un marcador en las coordenadas dadas
marker = gmaps.marker_layer([(latitud, longitud)], info_box_content='Punto de interés')
fig.add_layer(marker)

# Mostrar el mapa
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      11 fig = gmaps.figure(center=(latitud, longitud), zoom_level=12)
#      13 # Crear una capa de mapa satelital de Google
# ---> 14 capa_satelite = gmaps.satellite_layer()
#      15 fig.add_layer(capa_satelite)
#      17 # Agregar un marcador en las coordenadas dadas
#
# AttributeError: module 'gmaps' has no attribute 'satellite_layer'

# %%
### FINAL PROGRAM ###

import folium
import pandas as pd

# Load CSV file
df = pd.read_csv('data.csv')

# Extract latitude, longitude and label columns
latitudes = df['Latitude']
longitudes = df['Longitude']
# If we want to see the id of the image 
etiquetas = df['id']

# If we want to see magnetic field of the image 
# etiquetas = df['Magnetic North']

# Create a map with Google Maps tile provider (satellite)
mapa = folium.Map(location=[latitudes[0], longitudes[0]], tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}', attr='Google')

# Add markers for each point with labels
for lat, lon, etiqueta in zip(latitudes, longitudes, etiquetas):
    folium.Marker(location=[lat, lon], popup=etiqueta).add_to(mapa)

# Display the map
mapa.save('mapa.html')  # Guardar el mapa en un archivo HTML
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
